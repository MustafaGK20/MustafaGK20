# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_mercedes = pd.read_excel("merc.xlsx")
df_mercedes
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 0      2005   5200    Automatic    63000  325  32.1         1.8
# 1      2017  34948    Automatic    27000   20  61.4         2.1
# 2      2016  49948    Automatic     6200  555  28.0         5.5
# 3      2016  61948    Automatic    16000  325  30.4         4.0
# 4      2016  73948    Automatic     4000  325  30.1         4.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9
#
# [13119 rows x 7 columns]

# %%
df_mercedes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          13119 non-null  int64
#  1   price         13119 non-null  int64
#  2   transmission  13119 non-null  object
#  3   mileage       13119 non-null  int64
#  4   tax           13119 non-null  int64
#  5   mpg           13119 non-null  float64
#  6   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 717.6+ KB

# %%
df_mercedes.transmission = pd.Categorical(df_mercedes.transmission)
df_mercedes.dtypes
# Out:
# year               int64
# price              int64
# transmission    category
# mileage            int64
# tax                int64
# mpg              float64
# engineSize       float64
# dtype: object

# %%
df_mercedes.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df_mercedes.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
sns.displot(df_mercedes["price"], kde="hist", color="g")

# %%
sns.countplot(x=df_mercedes["year"], data=df_mercedes)
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
df_mercedes.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
df_mercedes.corr()["year"].sort_values()
# Out:
# mileage      -0.738027
# engineSize   -0.142147
# mpg          -0.094626
# tax           0.012480
# price         0.520712
# year          1.000000
# Name: year, dtype: float64

# %%
sns.scatterplot(x="mileage", y="price", data=df_mercedes)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
df_mercedes.sort_values("price",ascending=False).head(30)
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
df_mercedes.sort_values("price",ascending=True).head(30)
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(df_mercedes)
# Out:
# 13119

# %%
len(df_mercedes) * 0.01
# Out:
# 131.19

# %%
expensiveCar = df_mercedes.sort_values("price", ascending=False).iloc[:131]
expensiveCar
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# ...     ...     ...          ...      ...  ...   ...         ...
# 6196   2019   66890    Semi-Auto     1200  145  28.5         4.0
# 7266   2019   66699    Semi-Auto      630  145  28.5         4.0
# 7714   2019   66599    Semi-Auto     2104  145  22.4         4.0
# 7736   2019   66099    Semi-Auto     2918  145  27.4         4.0
# 1932   2020   65995    Semi-Auto      200  145  31.7         3.0
#
# [131 rows x 7 columns]

# %%
expensiveCar.describe()
# Out:
#               year          price       mileage         tax         mpg  \
# count   131.000000     131.000000    131.000000  131.000000  131.000000
# mean   2018.725191   86532.381679   3787.961832  157.977099   27.266412
# std       1.102818   23151.813090   5511.893754   67.078538    5.306855
# min    2011.000000   65995.000000      9.000000  145.000000   11.000000
# 25%    2019.000000   69814.500000    924.500000  145.000000   22.600000
# 50%    2019.000000   76989.000000   1755.000000  145.000000   28.000000
# 75%    2019.000000   94810.500000   3999.500000  145.000000   30.400000
# max    2020.000000  159999.000000  38247.000000  570.000000   52.300000
#
#        engineSize
# count  131.000000
# mean     4.116794
# std      0.685021
# min      2.900000
# 25%      4.000000
# 50%      4.000000
# 75%      4.000000
# max      6.200000

# %%
affordableCarPrices = df_mercedes.sort_values("price", ascending=False).iloc[131:]

# %%
affordableCarPrices
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 6177   2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191   2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  64999    Semi-Auto      119  145  40.9         3.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11816  2003    650       Manual   109090  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
affordableCarPrices.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
sns.displot(affordableCarPrices["price"], kde="hist", color="g")

# %%
df_mercedes.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
affordableCarPrices.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
expensiveCar.groupby("year").mean()["price"]
# Out:
# year
# 2011    149948.000000
# 2015     99850.000000
# 2016     74631.000000
# 2017     84066.833333
# 2018     92232.850000
# 2019     85172.156627
# 2020     84923.764706
# Name: price, dtype: float64

# %%
# 1970 model araba fiyatlarını çıkarttık. 
df_mercedes[df_mercedes.year != 1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
df_mercedess = affordableCarPrices

# %%
df_mercedess.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df_mercedess = df_mercedess[df_mercedess.year != 1970]

# %%
df_mercedess.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12987.000000  12987.000000   12987.000000  12987.000000  12987.000000
# mean    2017.285516  24074.855779   22133.367367    129.676215     55.438392
# std        2.189633   9866.601115   21197.472376     65.167429     15.025902
# min     1997.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17355.000000    6320.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15371.000000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31986.500000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12987.000000
# mean       2.051059
# std        0.532313
# min        0.000000
# 25%        1.700000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df_mercedess.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
df_mercedess = df_mercedess.drop("transmission", axis=1)

# %%
df_mercedess.head()
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 6177  2019  65990     5076  150  30.4         3.0
# 5779  2020  65990      999  145  28.0         4.0
# 3191  2020  65980     3999  145  28.0         4.0
# 4727  2019  65000     3398  145  27.2         4.0
# 8814  2019  64999      119  145  40.9         3.0

# %%
y = df_mercedess["price"].values
x = df_mercedess.drop("price", axis=1).values

# %%
y
# Out:
# array([65990, 65990, 65980, ...,  1490,  1350,   650], dtype=int64)

# %%
x
# Out:
# array([[2.01900e+03, 5.07600e+03, 1.50000e+02, 3.04000e+01, 3.00000e+00],
#        [2.02000e+03, 9.99000e+02, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        [2.02000e+03, 3.99900e+03, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        ...,
#        [2.00000e+03, 8.70000e+04, 2.65000e+02, 2.72000e+01, 3.20000e+00],
#        [2.01000e+03, 1.16126e+05, 1.45000e+02, 5.43000e+01, 2.00000e+00],
#        [2.00300e+03, 1.09090e+05, 2.35000e+02, 4.00000e+01, 1.40000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=10)

# %%
len(x_train)
# Out:
# 9090

# %%
len(x_test)
# Out:
# 3897

# %%
len(y_train)
# Out:
# 9090

# %%
len(y_test)
# Out:
# 3897

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_train
# Out:
# array([[0.82608696, 0.07228985, 0.03448276, 0.30619796, 0.33870968],
#        [0.86956522, 0.22407036, 0.25      , 0.27890842, 0.32258065],
#        [0.82608696, 0.11663365, 0.05172414, 0.29879741, 0.32258065],
#        ...,
#        [0.65217391, 0.25115541, 0.21551724, 0.27890842, 0.29032258],
#        [0.73913043, 0.11981513, 0.34482759, 0.18408881, 0.32258065],
#        [0.86956522, 0.06027436, 0.40517241, 0.20212766, 0.35483871]])

# %%
x_test
# Out:
# array([[0.81818182, 0.04323994, 0.03448276, 0.30619796, 0.33870968],
#        [0.81818182, 0.03752615, 0.34482759, 0.19287697, 0.32258065],
#        [1.        , 0.02242812, 0.25      , 0.29879741, 0.24193548],
#        ...,
#        [0.95454545, 0.05337557, 0.25      , 0.27890842, 0.32258065],
#        [0.81818182, 0.45964939, 0.        , 0.56290472, 0.32258065],
#        [0.95454545, 0.02586072, 0.25      , 0.26734505, 0.25806452]])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (9090, 5)

# %%
model = Sequential()

model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam", loss="mse")

# %%
model.fit(x_train, y_train, validation_data=(x_test,y_test), batch_size=250, epochs=300)
# Out:
# Epoch 1/300
# 37/37 [==============================] - 1s 5ms/step - loss: 672146880.0000 - val_loss: 688107328.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 2ms/step - loss: 672131904.0000 - val_loss: 688080256.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 1ms/step - loss: 672080128.0000 - val_loss: 687988096.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 1ms/step - loss: 671906752.0000 - val_loss: 687673024.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 2ms/step - loss: 671361920.0000 - val_loss: 686758528.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 2ms/step - loss: 669891712.0000 - val_loss: 684437056.0000
# Epoch 7/300
# 37/37 [==============================] - 0s 2ms/step - loss: 666456960.0000 - val_loss: 679360832.0000
# Epoch 8/300
# 37/37 [==============================] - 0s 2ms/step - loss: 659455104.0000 - val_loss: 669543360.0000
# Epoch 9/300
# ...

# %%
kayipVerisi = pd.DataFrame(model.history.history)

# %%
kayipVerisi.head()
# Out:
#           loss     val_loss
# 0  672146880.0  688107328.0
# 1  672131904.0  688080256.0
# 2  672080128.0  687988096.0
# 3  671906752.0  687673024.0
# 4  671361920.0  686758528.0

# %%
kayipVerisi.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
tahminDizisi = model.predict(x_test)

# %%
tahminDizisi
# Out:
# array([[20581.227],
#        [22099.232],
#        [24785.844],
#        ...,
#        [25343.852],
#        [10265.43 ],
#        [24254.418]], dtype=float32)

# %%
mean_absolute_error(y_test, tahminDizisi)
# Out:
# 3405.057462258127

# %%
mean_squared_error(y_test, tahminDizisi)
# Out:
# 23670972.26952942

# %%
df_mercedess.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12987.000000  12987.000000   12987.000000  12987.000000  12987.000000
# mean    2017.285516  24074.855779   22133.367367    129.676215     55.438392
# std        2.189633   9866.601115   21197.472376     65.167429     15.025902
# min     1997.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17355.000000    6320.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15371.000000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31986.500000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12987.000000
# mean       2.051059
# std        0.532313
# min        0.000000
# 25%        1.700000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.scatter(y_test, tahminDizisi)
plt.plot(y_test, y_test, "g-*")

# %%
df_mercedess.iloc[2]
# Out:
# year           2020.0
# price         65980.0
# mileage        3999.0
# tax             145.0
# mpg              28.0
# engineSize        4.0
# Name: 3191, dtype: float64

# %%
newCar = df_mercedess.drop("price", axis=1).iloc[2]

# %%
newCar
# Out:
# year          2020.0
# mileage       3999.0
# tax            145.0
# mpg             28.0
# engineSize       4.0
# Name: 3191, dtype: float64

# %%
type(newCar)
# Out:
# pandas.core.series.Series

# %%
newCarPrediction = scaler.transform(newCar.values.reshape(-1,5))

# %%
model.predict(newCarPrediction)
# Out:
# array([[61405.105]], dtype=float32)
